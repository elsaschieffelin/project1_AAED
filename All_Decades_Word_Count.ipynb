# %%
#Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Read csv files
csv_pathc = "lyrics_output/df_words_United_States_Top_50.csv"
csv_path1 = "lyrics_output/df_words_All_Out_10s.csv"
csv_path0 = "lyrics_output/df_words_All_Out_00s.csv"
csv_path9 = "lyrics_output/df_words_All_Out_90s.csv"
csv_path8 = "lyrics_output/df_words_All_Out_80s.csv"
csv_path7 = "lyrics_output/df_words_All_Out_70s.csv"
csv_path6 = "lyrics_output/df_words_All_Out_60s.csv"
csv_path5 = "lyrics_output/df_words_All_Out_50s.csv"

# %%
#Create dataframes for each decade
df_c = pd.read_csv(csv_pathc)
df_10s = pd.read_csv(csv_path1)
df_00s = pd.read_csv(csv_path0)
df_90s = pd.read_csv(csv_path9)
df_80s = pd.read_csv(csv_path8)
df_70s = pd.read_csv(csv_path7)
df_60s = pd.read_csv(csv_path6)
df_50s = pd.read_csv(csv_path5)

# %%
#Read in the top 50 most commonly used English words (OEC standard)
lines = list()
fh = open("top50_words.txt")
for line in fh:
    line = line.rstrip()
    lines.append(line)
lines
# Out:
# ['be',
#  'to',
#  'of',
#  'and',
#  'a',
#  'in',
#  'that',
#  'have',
#  'i',
#  'it',
#  'for',
#  'not',
#  'on',
#  'with',
#  'he',
#  'as',
#  'you',
#  'do',
#  'at',
#  'this',
#  'but',
#  'his',
#  'by',
#  'from',
#  'they',
#  'we',
#  'say',
#  'her',
#  'she',
#  'or',
#  'an',
#  'will',
#  'my',
#  'one',
#  'all',
#  'would',
#  'there',
#  'their',
#  'what',
#  'so',
#  'up',
#  'out',
#  'if',
#  'about',
#  'who',
#  'get',
#  'which',
#  'go',
#  'me',
#  'when',
#  '']

# %%
#Sorting and editing
df_current = df_c.sort_values("count", ascending = False)
df_current = df_current.rename(columns = {"Unnamed: 0": "words"})

#Remove the most common English words
df_cleaned=df_current[~df_current['words'].isin(lines)]
df_current_sample = df_cleaned.head(10)
df_current_sample.head()
# Out:
#     words  count
# 17    the    696
# 20    i'm    385
# 19   yeah    331
# 131  like    218
# 73     no    190

# %%
#Create bar chart
words_10 = df_current_sample["words"] #x
counts = df_current_sample["count"] #y
width = 0.8
fig, ax = plt.subplots(figsize=(12,5))
rects = ax.bar(words_10, counts, width, color=('c','c','c','c','c','y','y','y','y','y'))
ax.set_title("Top 10 words in current US Top 50 Hits")
ax.set_xlabel("Words")
ax.set_ylabel("Word Frequency")
ax.set_ylim(0,750)
#label bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.0*height,
        '%d' % int(height), ha='center', va='bottom')
autolabel(rects)

plt.savefig("decade_charts/10_top_words_current.png")
plt.show()

# %%
#Sorting and editing
df_10s=df_10s.sort_values("count", ascending = False)
df_10s = df_10s.rename(columns={"Unnamed: 0": "words"})

#Remove most common English words
df_cleaned=df_10s[~df_10s['words'].isin(lines)]
df_10s_sample = df_cleaned.head(10)
df_10s_sample
# Out:
#      words  count
# 11     the    483
# 13     i'm    212
# 21    your    199
# 101   know    170
# 169     oh    162
# 532   yeah    159
# 79   don't    156
# 90    like    151
# 262   love    142
# 648  'bout    137

# %%
#Create bar chart
words_10 = df_10s_sample["words"] #x
counts = df_10s_sample["count"] #y
width = 0.8
fig, ax = plt.subplots(figsize=(12,5))
rects = ax.bar(words_10, counts, width, color=('c','c','c','c','c','y','y','y','y','y'))
ax.set_title("Top 10 words in 2010s' Top Songs")
ax.set_xlabel("Words")
ax.set_ylabel("Word Frequency")
ax.set_ylim(0,550)

#label bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.0*height,
        '%d' % int(height), ha='center', va='bottom')
autolabel(rects)

plt.savefig("decade_charts/10_top_words_2010s.png")
plt.show()

# %%
#Sorting and editing
df_00s = df_00s.sort_values("count", ascending = False)
df_00s = df_00s.rename(columns = {"Unnamed: 0": "words"})

#Remove most common English words
df_cleaned=df_00s[~df_00s['words'].isin(lines)]
df_00s_sample = df_cleaned.head(10)
df_00s_sample
# Out:
#      words  count
# 10     the    764
# 44    your    464
# 190    i'm    376
# 81    just    203
# 404  hands    196
# 95      no    187
# 650  what?    181
# 79      oh    177
# 883     la    162
# 242   love    161

# %%
#Create bar chart
words_10 = df_00s_sample["words"] #x
counts = df_00s_sample["count"] #y
width = 0.8
fig, ax = plt.subplots(figsize=(12,5))
rects = ax.bar(words_10, counts, width, color=('c','c','c','c','c','y','y','y','y','y'))
ax.set_title("Top 10 words in 2000s' Top Songs")
ax.set_xlabel("Words")
ax.set_ylabel("Word Frequency")
ax.set_ylim(0,850)

#label bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.0*height,
        '%d' % int(height), ha='center', va='bottom')
autolabel(rects)

plt.savefig("decade_charts/10_top_words_2000s.png")
plt.show()

# %%
#Sorting and editing
df_90s = df_90s.sort_values("count", ascending = False)
df_90s = df_90s.rename(columns = {"Unnamed: 0": "words"})

#Remove most common English words
df_cleaned=df_90s[~df_90s['words'].isin(lines)]
df_90s_sample = df_cleaned.head(10)
df_90s_sample
# Out:
#        words  count
# 34       the    612
# 92   houston    206
# 70      your    184
# 53      it's    174
# 83    sawyer    170
# 97        is    156
# 22      know    155
# 3       want    154
# 112      i'm    153
# 268     love    138

# %%
#Create bar chart
words_10 = df_90s_sample["words"] #x
counts = df_90s_sample["count"] #y
width = 0.8
fig, ax = plt.subplots(figsize=(12,5))
rects = ax.bar(words_10, counts, width, color=('c','c','c','c','c','y','y','y','y','y'))
ax.set_title("Top 10 words in 1990s' Top Songs")
ax.set_xlabel("Words")
ax.set_ylabel("Word Frequency")
ax.set_ylim(0,700)

#label bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.0*height,
        '%d' % int(height), ha='center', va='bottom')
autolabel(rects)

plt.savefig("decade_charts/10_top_words_1990s.png")
plt.show()

# %%
#Sorting and editing
df_80s = df_80s.sort_values("count", ascending = False)
df_80s = df_80s.rename(columns = {"Unnamed: 0": "words"})

#Remove most common English words
df_cleaned=df_80s[~df_80s['words'].isin(lines)]
df_80s_sample = df_cleaned.head(10)
df_80s_sample
# Out:
#       words  count
# 34      the    496
# 11     your    131
# 90      i'm    119
# 39     it's     89
# 64     love     75
# 165  chorus     72
# 288    like     66
# 128    know     66
# 189   don't     65
# 71      got     64

# %%
#Create bar chart
words_10 = df_80s_sample["words"] #x
counts = df_80s_sample["count"] #y
width = 0.8
fig, ax = plt.subplots(figsize=(12,5))
rects = ax.bar(words_10, counts, width, color=('c','c','c','c','c','y','y','y','y','y'))
ax.set_title("Top 10 words in 1980s' Top Songs")
ax.set_xlabel("Words")
ax.set_ylabel("Word Frequency")
ax.set_ylim(0,550)

#label bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.0*height,
        '%d' % int(height), ha='center', va='bottom')
autolabel(rects)

plt.savefig("decade_charts/10_top_words_1980s.png")
plt.show()

# %%
#Sorting and editing
df_70s = df_70s.sort_values("count", ascending = False)
df_70s = df_70s.rename(columns = {"Unnamed: 0": "words"})

#Remove most common English words
df_cleaned=df_70s[~df_70s['words'].isin(lines)]
df_70s_sample = df_cleaned.head(10)
df_70s_sample
# Out:
#          words  count
# 11         the    560
# 44         i'm    147
# 191       your    108
# 115       just     94
# 14        it's     88
# 121         is     86
# 685  goodnight     86
# 0        verse     85
# 311       love     78
# 27        know     75

# %%
#Create bar chart
words_10 = df_70s_sample["words"] #x
counts = df_70s_sample["count"] #y
width = 0.8
fig, ax = plt.subplots(figsize=(12,5))
rects = ax.bar(words_10, counts, width, align="center", color=('c','c','c','c','c','y','y','y','y','y'))
ax.set_title("Top 10 words in 1970s' Top Songs")
ax.set_xlabel("Words")
ax.set_ylabel("Word Frequency")
ax.set_ylim(0,650)

#label bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.0*height,
        '%d' % int(height), ha='center', va='bottom')
autolabel(rects)

plt.savefig("decade_charts/10_top_words_1970s.png")
plt.show()

# %%
#Sorting and editing
df_60s = df_60s.sort_values("count", ascending = False)
df_60s = df_60s.rename(columns = {"Unnamed: 0": "words"})

#Remove most common English words
df_cleaned=df_60s[~df_60s['words'].isin(lines)]
df_60s_sample = df_cleaned.head(10)
df_60s_sample
# Out:
#     words  count
# 3     the    330
# 34   your     64
# 405   i'm     61
# 195  love     56
# 24   like     55
# 23     is     55
# 93   baby     53
# 411  time     49
# 294  just     44
# 27   here     41

# %%
#Create bar chart
words_10 = df_60s_sample["words"] #x
counts = df_60s_sample["count"] #y
width = 0.8
fig, ax = plt.subplots(figsize=(12,5))
rects = ax.bar(words_10, counts, width, color=('c','c','c','c','c','y','y','y','y','y'))
ax.set_title("Top 10 words in 1960s' Top Songs")
ax.set_xlabel("Words")
ax.set_ylabel("Word Frequency")
ax.set_ylim(0,400)

#label bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.0*height,
        '%d' % int(height), ha='center', va='bottom')
autolabel(rects)

plt.savefig("decade_charts/10_top_words_1960s.png")
plt.show()

# %%
#Sorting and editing
df_50s = df_50s.sort_values("count", ascending = False)
df_50s = df_50s.rename(columns = {"Unnamed: 0": "words"})

#Remove most common English words
df_cleaned=df_50s[~df_50s['words'].isin(lines)]
df_50s_sample = df_cleaned.head(10)
df_50s_sample
# Out:
#      words  count
# 18     the    180
# 37    love     52
# 83    your     37
# 59     yes     36
# 1    don't     35
# 97      is     35
# 690  tweet     35
# 38    know     31
# 157   it's     31
# 203  dream     27

# %%
#Create bar chart
words_10 = df_50s_sample["words"] #x
counts = df_50s_sample["count"] #y
width = 0.8
fig, ax = plt.subplots(figsize=(12,5))
rects = ax.bar(words_10, counts, width, align="center", color=('c','c','c','c','c','y','y','y','y','y'))
ax.set_title("Top 10 words in 1950s' Top Songs")
ax.set_xlabel("Words")
ax.set_ylabel("Word Frequency")
ax.set_ylim(0,200)

#label bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.0*height,
        '%d' % int(height), ha='center', va='bottom')
autolabel(rects)

plt.savefig("decade_charts/10_top_words_1950s.png")
plt.show()
