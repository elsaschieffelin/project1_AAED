# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_path="./results.csv"
df=pd.read_csv(csv_path)

# %%
df.reset_index()
# Out:
#             Column1  All Out 50s  All Out 60s  All Out 70s  All Out 80s  \
# 0                 i        162.0        244.0        459.0        386.0
# 1               you        150.0        244.0        298.0        392.0
# 2               the        155.0        324.0        561.0        515.0
# 3                 a         81.0        176.0        347.0        273.0
# 4                my         64.0         96.0        236.0        117.0
# 5                me         67.0        154.0        230.0        158.0
# 6                it         39.0         65.0        119.0        133.0
# 7               i'm         14.0         72.0        139.0        117.0
# 8                to         67.0        149.0        269.0        311.0
# 9               and        117.0        198.0        395.0        236.0
# 10             yeah         16.0         33.0         38.0         22.0
# 11             that         52.0         71.0        129.0         84.0
# ...

# %%
df.set_index("Column1")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Column1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-26d591202d8e> in <module>
# ----> 1 df.set_index("Column1")
#
# ...

# %%
bwordz = ["bitch", "bitches", "bitch!", "bitching", "fuk.a.bitch", "bitchin’"]

# %%
df.head()
# Out:
#          All Out 50s  All Out 60s  All Out 70s  All Out 80s  All Out 90s  \
# Column1
# i              162.0        244.0        459.0        386.0        774.0
# you            150.0        244.0        298.0        392.0        867.0
# the            155.0        324.0        561.0        515.0        590.0
# a               81.0        176.0        347.0        273.0        352.0
# my              64.0         96.0        236.0        117.0        219.0
#
#          All Out 00s  All Out 10s  US Top 50  Top_Male_Artists_of_2018  \
# Column1
# i              688.0        645.0     1083.0                     336.0
# you            811.0        902.0      973.0                     335.0
# the            743.0        500.0      696.0                     300.0
# a              391.0        262.0      520.0                     297.0
# my             285.0        274.0      408.0                     152.0
#
#          Top_Female_Artists_of_2018      ...        Elton John  Radiohead  \
# ...

# %%
bwordz_df = df.loc[bwordz]
# Out:
#              All Out 50s  All Out 60s  All Out 70s  All Out 80s  All Out 90s  \
# Column1
# bitch                NaN          NaN          2.0         33.0          NaN
# bitches              NaN          NaN          NaN          1.0          NaN
# bitch!               NaN          NaN          NaN          NaN          NaN
# bitching             NaN          NaN          NaN          NaN          3.0
# fuk.a.bitch          NaN          NaN          1.0          NaN          NaN
# bitchin’           NaN          NaN          NaN          NaN          NaN
#
#              All Out 00s  All Out 10s  US Top 50  Top_Male_Artists_of_2018  \
# Column1
# bitch                5.0          NaN       79.0                      19.0
# bitches              NaN          2.0       18.0                       4.0
# bitch!               NaN          NaN        1.0                       NaN
# bitching             NaN          NaN        NaN                       NaN
# ...

# %%
bwords=[]
fwords=[]
swords=[]
dwords=[]
for items in list(df.index.values): 
    if "bitch" in items: 
        bwords.append(items)
    if "fuck" in items:
        fwords.append(items)
    if "shit" in items:
        swords.append(items)
    if "dick" in items:
        dwords.append(items)
print(bwords)
print(fwords)
print(swords)
print(dwords)
# Out:
# ['bitch', 'bitches', 'bitch!', 'bitching', 'fuk.a.bitch', 'bitchin’', 'bitch-ass']
# ['fuck', "fuckin'", 'fucking', 'fucked', "fuckin'—", 'fucking—', 'motherfucker', 'morherfuckin', 'fucker', 'fucks', 'motherfucking', 'fuckin', 'mothafucker', 'fucked—other', "motherfuckin'", 'motherfuckin’', 'mothafucka!"', 'fuckers', 'motherfuckin', 'motherfuckers', "mothafuckin'", 'motherfuckerss', 'f-f-fuck', 'mothafucka']
# ['shit', "shit's", 'shits', 'shitty', 'bullshit"', 'shit?', 'bullshit', 'shit"', 'bullshit!', 'shitting', 'shit!', 'shit.']
# ['dick', 'dicked', 'dick!', 'dick?']

# %%
bwords_df=df.loc[bwords]
fwords_df=df.loc[fwords]
swords_df=df.loc[swords]
dwords_df=df.loc[dwords]

# %%
bwords_df=bwords_df.
