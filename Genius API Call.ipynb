# %%
import requests
from bs4 import BeautifulSoup

api_key = "-6h7g0eU0bZhAiK7GquXvfaR2no3cgHbYHeR7u3Bt5bg1UQBVl-gYVrjOA5k3TPD"



# above will allow us to reformat HTML easily

#creating some functions


def request_song_info(song_title, artist_name):
    main_url = 'https://api.genius.com/search'
    headers = {'Authorization': 'Bearer ' + api_key}
    data = {'q': song_title + ' ' + artist_name}
    response = requests.get(main_url, data=data, headers=headers)

    return response

def get_song_lyrics(url):
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    lyrics = html.find('div', class_='lyrics').get_text()

    return lyrics

def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

# %%
song_title = "Bohemian Rhapsody"
artist_name = "Queen"

request_song_info(song_title, artist_name).text

response = request_song_info(song_title, artist_name)
data = response.json()
remote_song_info = None

for hit in data['response']['hits']:
    if artist_name.lower() in hit['result']['primary_artist']['name'].lower():
        remote_song_info = hit
        break
        
#remote_song_info
    
if remote_song_info:
    song_url = remote_song_info['result']['url']
    
#song_url
    clean_lyrics=get_song_lyrics(song_url).replace("\n"," ")

    clean_lyrics

#word_count(clean_lyrics)
# Out:
# '  [In'

# %%
data
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 11,
#      'api_path': '/songs/1063',
#      'full_title': 'Bohemian Rhapsody by\xa0Queen',
#      'header_image_thumbnail_url': 'https://images.genius.com/ff9ddef65ab95da61354ce587748e2e9.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/ff9ddef65ab95da61354ce587748e2e9.600x600x1.png',
#      'id': 1063,
#      'lyrics_owner_id': 3,
#      'lyrics_state': 'complete',
#      'path': '/Queen-bohemian-rhapsody-lyrics',
#      'pyongs_count': 486,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/ff9ddef65ab95da61354ce587748e2e9.300x300x1.png',
#      'stats': {'hot': False,
#       'unreviewed_annotations': 0,
#       'concurrents': 22,
#       'pageviews': 4888184},
#      'title': 'Bohemian Rhapsody',
#      'title_with_featured': 'Bohemian Rhapsody',
#      'url': 'https://genius.com/Queen-bohemian-rhapsody-lyrics',
#      'primary_artist': {'api_path': '/artists/563',
#       'header_image_url': 'https://images.genius.com/fe643c1cd9be97167e97a99c182e6051.960x360x1.jpg',
#       'id': 563,
#       'image_url': 'https://images.genius.com/781f51bb7041e6b7eeec820fbc413e75.1000x750x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Queen',
#       'url': 'https://genius.com/artists/Queen'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/2123526',
#      'full_title': 'Bohemian Rhapsody by\xa0The\xa0Muppets (Ft.\xa0Queen)',
#      'header_image_thumbnail_url': 'https://images.genius.com/0ae6adf3fd12f1965f2c819dcddb3565.300x299x1.jpg',
#      'header_image_url': 'https://images.genius.com/0ae6adf3fd12f1965f2c819dcddb3565.480x479x1.jpg',
#      'id': 2123526,
#      'lyrics_owner_id': 1549345,
#      'lyrics_state': 'complete',
#      'path': '/The-muppets-bohemian-rhapsody-lyrics',
#      'pyongs_count': 1,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/0ae6adf3fd12f1965f2c819dcddb3565.300x299x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0, 'pageviews': 6009},
#      'title': 'Bohemian Rhapsody',
#      'title_with_featured': 'Bohemian Rhapsody (Ft.\xa0Queen)',
#      'url': 'https://genius.com/The-muppets-bohemian-rhapsody-lyrics',
#      'primary_artist': {'api_path': '/artists/334479',
#       'header_image_url': 'https://images.genius.com/93de756dd2915c1de17adf7bc86e98ff.1000x488x1.jpg',
#       'id': 334479,
#       'image_url': 'https://images.genius.com/93de756dd2915c1de17adf7bc86e98ff.1000x488x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Muppets',
#       'url': 'https://genius.com/artists/The-muppets'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 6,
#      'api_path': '/songs/4276260',
#      'full_title': 'MAIN BITCH by\xa0M¥SS\xa0KETA',
#      'header_image_thumbnail_url': 'https://images.genius.com/6f05ec6a1f7d31777d6b941d873446e0.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/6f05ec6a1f7d31777d6b941d873446e0.960x960x1.jpg',
#      'id': 4276260,
#      'lyrics_owner_id': 1837201,
#      'lyrics_state': 'complete',
#      'path': '/Mss-keta-main-bitch-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/6f05ec6a1f7d31777d6b941d873446e0.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'MAIN BITCH',
#      'title_with_featured': 'MAIN BITCH',
#      'url': 'https://genius.com/Mss-keta-main-bitch-lyrics',
#      'primary_artist': {'api_path': '/artists/667242',
#       'header_image_url': 'https://images.genius.com/8c1a5953b18feb46590f9ddc0b592550.1000x748x1.jpg',
#       'id': 667242,
#       'image_url': 'https://images.genius.com/4fb130b5cbc266c0afde7b60f59fa0f8.868x868x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': True,
#       'name': 'M¥SS KETA',
#       'url': 'https://genius.com/artists/Mss-keta',
#       'iq': 1477}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/3746637',
#      'full_title': 'BBC Radio 1 Biggest Weekend 2018 Setlist by\xa0Panic!\xa0at the Disco',
#      'header_image_thumbnail_url': 'https://images.genius.com/0c9c63cfdae0d165c1c81cbd4d14c7d4.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/0c9c63cfdae0d165c1c81cbd4d14c7d4.544x544x1.jpg',
#      'id': 3746637,
#      'lyrics_owner_id': 1873201,
#      'lyrics_state': 'complete',
#      'path': '/Panic-at-the-disco-bbc-radio-1-biggest-weekend-2018-setlist-annotated',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/0c9c63cfdae0d165c1c81cbd4d14c7d4.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'BBC Radio 1 Biggest Weekend 2018 Setlist',
#      'title_with_featured': 'BBC Radio 1 Biggest Weekend 2018 Setlist',
#      'url': 'https://genius.com/Panic-at-the-disco-bbc-radio-1-biggest-weekend-2018-setlist-annotated',
#      'primary_artist': {'api_path': '/artists/50838',
#       'header_image_url': 'https://images.genius.com/0c9c63cfdae0d165c1c81cbd4d14c7d4.544x544x1.jpg',
#       'id': 50838,
#       'image_url': 'https://images.genius.com/0c9c63cfdae0d165c1c81cbd4d14c7d4.544x544x1.jpg',
#       'is_meme_verified': True,
#       'is_verified': True,
#       'name': 'Panic! at the Disco',
#       'url': 'https://genius.com/artists/Panic-at-the-disco',
#       'iq': 22267}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 6,
#      'api_path': '/songs/4219394',
#      'full_title': 'JANUARY 2K19 by\xa0Myka\xa0Davis',
#      'header_image_thumbnail_url': 'https://images.genius.com/147322bdc122519c74c3eb8cd5a783cd.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/147322bdc122519c74c3eb8cd5a783cd.500x500x1.png',
#      'id': 4219394,
#      'lyrics_owner_id': 3665313,
#      'lyrics_state': 'complete',
#      'path': '/Myka-davis-january-2k19-annotated',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/147322bdc122519c74c3eb8cd5a783cd.300x300x1.png',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'JANUARY 2K19',
#      'title_with_featured': 'JANUARY 2K19',
#      'url': 'https://genius.com/Myka-davis-january-2k19-annotated',
#      'primary_artist': {'api_path': '/artists/1692558',
#       'header_image_url': 'https://images.genius.com/7cb564c97f3d4523057d7caa6b898295.960x932x1.png',
#       'id': 1692558,
#       'image_url': 'https://images.genius.com/f785ca6eeed589728b7842ebbbd46a59.720x720x1.png',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Myka Davis',
#       'url': 'https://genius.com/artists/Myka-davis',
#       'iq': 5901}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/2284290',
#      'full_title': 'Too Bad by\xa0Cam\xa0James',
#      'header_image_thumbnail_url': 'https://images.genius.com/8a502ab1cc79134e2a01a2d1d40638bf.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/8a502ab1cc79134e2a01a2d1d40638bf.1000x1000x1.jpg',
#      'id': 2284290,
#      'lyrics_owner_id': 144562,
#      'lyrics_state': 'complete',
#      'path': '/Cam-james-too-bad-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8a502ab1cc79134e2a01a2d1d40638bf.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Too Bad',
#      'title_with_featured': 'Too Bad',
#      'url': 'https://genius.com/Cam-james-too-bad-lyrics',
#      'primary_artist': {'api_path': '/artists/169037',
#       'header_image_url': 'https://images.genius.com/5d2717ac92a62dabe8b2c1c415a5be21.1000x429x1.jpg',
#       'id': 169037,
#       'image_url': 'https://images.genius.com/8a502ab1cc79134e2a01a2d1d40638bf.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Cam James',
#       'url': 'https://genius.com/artists/Cam-james',
#       'iq': 3974}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/3903700',
#      'full_title': 'Bohemian Rhapsody (Live) by\xa0Queen',
#      'header_image_thumbnail_url': 'https://images.genius.com/fb3c20b23d0fd8a11369389031e2c49e.224x224x1.jpg',
#      'header_image_url': 'https://images.genius.com/fb3c20b23d0fd8a11369389031e2c49e.224x224x1.jpg',
#      'id': 3903700,
#      'lyrics_owner_id': 4365014,
#      'lyrics_state': 'complete',
#      'path': '/Queen-bohemian-rhapsody-live-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/fb3c20b23d0fd8a11369389031e2c49e.224x224x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 1},
#      'title': 'Bohemian Rhapsody (Live)',
#      'title_with_featured': 'Bohemian Rhapsody (Live)',
#      'url': 'https://genius.com/Queen-bohemian-rhapsody-live-lyrics',
#      'primary_artist': {'api_path': '/artists/563',
#       'header_image_url': 'https://images.genius.com/fe643c1cd9be97167e97a99c182e6051.960x360x1.jpg',
#       'id': 563,
#       'image_url': 'https://images.genius.com/781f51bb7041e6b7eeec820fbc413e75.1000x750x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Queen',
#       'url': 'https://genius.com/artists/Queen'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/3973458',
#      'full_title': 'Google Translate Sings: "Bohemian Rhapsody" by Queen by\xa0Malinda',
#      'header_image_thumbnail_url': 'https://images.genius.com/d17f16e1dc878a0be9a4b5a04c6dd68a.300x225x1.jpg',
#      'header_image_url': 'https://images.genius.com/d17f16e1dc878a0be9a4b5a04c6dd68a.480x360x1.jpg',
#      'id': 3973458,
#      'lyrics_owner_id': 6867920,
#      'lyrics_state': 'incomplete',
#      'path': '/Malinda-google-translate-sings-bohemian-rhapsody-by-queen-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/d17f16e1dc878a0be9a4b5a04c6dd68a.300x225x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Google Translate Sings: "Bohemian Rhapsody" by Queen',
#      'title_with_featured': 'Google Translate Sings: "Bohemian Rhapsody" by Queen',
#      'url': 'https://genius.com/Malinda-google-translate-sings-bohemian-rhapsody-by-queen-lyrics',
#      'primary_artist': {'api_path': '/artists/1460051',
#       'header_image_url': 'https://images.genius.com/cd1df02791eb3033df0dbd49ea4fe655.720x730x1.png',
#       'id': 1460051,
#       'image_url': 'https://images.genius.com/6e9df997ea6b0dfa83d18d629b5cc266.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Malinda',
#       'url': 'https://genius.com/artists/Malinda'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 324,
#      'api_path': '/songs/2282952',
#      'full_title': 'Road Trip Playlist Songs by\xa0Genius\xa0Lists',
#      'header_image_thumbnail_url': 'https://images.rapgenius.com/14128739be5acc7c2d832f15e96abc14.300x112x1.jpg',
#      'header_image_url': 'https://images.rapgenius.com/14128739be5acc7c2d832f15e96abc14.495x185x1.jpg',
#      'id': 2282952,
#      'lyrics_owner_id': 1217557,
#      'lyrics_state': 'complete',
#      'path': '/Genius-lists-road-trip-playlist-songs-annotated',
#      'pyongs_count': 3,
#      'song_art_image_thumbnail_url': 'https://images.rapgenius.com/14128739be5acc7c2d832f15e96abc14.300x112x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 7},
#      'title': 'Road Trip Playlist Songs',
#      'title_with_featured': 'Road Trip Playlist Songs',
#      'url': 'https://genius.com/Genius-lists-road-trip-playlist-songs-annotated',
#      'primary_artist': {'api_path': '/artists/614215',
#       'header_image_url': 'https://images.genius.com/96df68348b42dd1e942857db4fc52228.266x266x1.jpg',
#       'id': 614215,
#       'image_url': 'https://images.genius.com/96df68348b42dd1e942857db4fc52228.266x266x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Genius Lists',
#       'url': 'https://genius.com/artists/Genius-lists'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/4153659',
#      'full_title': "Paige's Top 100 Songs: 2018 by\xa0This\xa0Autumn Eve",
#      'header_image_thumbnail_url': 'https://images.genius.com/7442f76195115bedf3b80aba27520e80.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/7442f76195115bedf3b80aba27520e80.1000x1000x1.jpg',
#      'id': 4153659,
#      'lyrics_owner_id': 3365031,
#      'lyrics_state': 'complete',
#      'path': '/This-autumn-eve-paiges-top-100-songs-2018-annotated',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/7442f76195115bedf3b80aba27520e80.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': "Paige's Top 100 Songs: 2018",
#      'title_with_featured': "Paige's Top 100 Songs: 2018",
#      'url': 'https://genius.com/This-autumn-eve-paiges-top-100-songs-2018-annotated',
#      'primary_artist': {'api_path': '/artists/1328854',
#       'header_image_url': 'https://images.genius.com/44e66f52c0d0f47ee1775fcfd76fac5d.1000x563x1.jpg',
#       'id': 1328854,
#       'image_url': 'https://images.genius.com/9fcfd3c9fe298707c1813132093956cc.256x192x65.gif',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'This Autumn Eve',
#       'url': 'https://genius.com/artists/This-autumn-eve',
#       'iq': 157222}}}]}}
