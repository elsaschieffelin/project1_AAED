# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_path="./results.csv"
df=pd.read_csv(csv_path)

# %%
df.reset_index()
# Out:
#        index       Column1  All Out 50s  All Out 60s  All Out 70s  \
# 0          0             i        162.0        244.0        459.0
# 1          1           you        150.0        244.0        298.0
# 2          2           the        155.0        324.0        561.0
# 3          3             a         81.0        176.0        347.0
# 4          4            my         64.0         96.0        236.0
# 5          5            me         67.0        154.0        230.0
# 6          6            it         39.0         65.0        119.0
# 7          7           i'm         14.0         72.0        139.0
# 8          8            to         67.0        149.0        269.0
# 9          9           and        117.0        198.0        395.0
# 10        10          yeah         16.0         33.0         38.0
# 11        11          that         52.0         71.0        129.0
# 12        12            on         35.0         77.0        105.0
# ...

# %%
df = df.set_index("Column1")

# %%
df = df.fillna(value = 0)

# %%
bwords=[]
fwords=[]
swords=[]
dwords=[]
for items in list(df.index.values): 
    if "bitch" in items: 
        bwords.append(items)
    if "fuck" in items:
        fwords.append(items)
    if "shit" in items:
        swords.append(items)
    if "dick" in items:
        dwords.append(items)
print(bwords)
print(fwords)
print(swords)
print(dwords)
# Out:
# ['bitch', 'bitches', 'bitch!', 'bitching', 'fuk.a.bitch', 'bitchin’', 'bitch-ass']
# ['fuck', "fuckin'", 'fucking', 'fucked', "fuckin'—", 'fucking—', 'motherfucker', 'morherfuckin', 'fucker', 'fucks', 'motherfucking', 'fuckin', 'mothafucker', 'fucked—other', "motherfuckin'", 'motherfuckin’', 'mothafucka!"', 'fuckers', 'motherfuckin', 'motherfuckers', "mothafuckin'", 'motherfuckerss', 'f-f-fuck', 'mothafucka']
# ['shit', "shit's", 'shits', 'shitty', 'bullshit"', 'shit?', 'bullshit', 'shit"', 'bullshit!', 'shitting', 'shit!', 'shit.']
# ['dick', 'dicked', 'dick!', 'dick?']

# %%
bwords=df.loc[bwords]
fwords=df.loc[fwords]
swords=df.loc[swords]
dwords=df.loc[dwords]

# %%
fwords["All Out 10s"]
# Out:
# Column1
# fuck               1.0
# fuckin'            0.0
# fucking            1.0
# fucked             0.0
# fuckin'—         0.0
# fucking—         0.0
# motherfucker       0.0
# morherfuckin       0.0
# fucker             0.0
# fucks              0.0
# motherfucking      0.0
# fuckin             0.0
# mothafucker        0.0
# fucked—other     0.0
# motherfuckin'      0.0
# motherfuckin’    0.0
# mothafucka!"       0.0
# fuckers            0.0
# motherfuckin       0.0
# motherfuckers      0.0
# mothafuckin'       0.0
# motherfuckerss     0.0
# f-f-fuck           0.0
# mothafucka         0.0
# Name: All Out 10s, dtype: float64

# %%
df.columns
# Out:
# Index(['All Out 50s', 'All Out 60s', 'All Out 70s', 'All Out 80s',
#        'All Out 90s', 'All Out 00s', 'All Out 10s', 'US Top 50',
#        'Top_Male_Artists_of_2018', 'Top_Female_Artists_of_2018', 'Eminem',
#        'Beatles', 'Prince', 'Nina Simone', 'Lady Gaga', 'Justin Bieber',
#        'John Mayer', 'Depeche Mode', 'Ed Sheeran', 'Aretha Franklin',
#        'Ed Sheeran2', 'Adele', 'Tom Petty', 'Metallica', 'Madonna',
#        'Stevie Wonder', 'Earth Wind And Fire', 'Drake', 'Elton John',
#        'Radiohead', 'Kendrick_Lamar', 'Frank_Sinatra', 'Red Hot Chili Peppers',
#        'Michael Buble', 'Beyonce', 'John Legend', 'ACDC', 'All Playlists'],
#       dtype='object')

# %%
b_all = bwords["All Playlists"].sum()
f_all = fwords["All Playlists"].sum()
s_all = swords["All Playlists"].sum()
d_all = dwords["All Playlists"].sum()
decades=["1950s", "1960s", "1970s", "1980s", "1990s", "2000s", "2010s", "All Playlists"]

# %%
barwidth=0.25

x1 = np.arange(len(b_words()))
x2 = [x + barwidth for x in x1]
x3 = [x + barwidth for x in x2]
x4 = [x + barwidth for x in x3]
print(x1)
print(x2)
print(x3)
print(x4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fd9ed58c9d33> in <module>
#       1 barwidth=0.25
#       2
# ----> 3 x1 = np.arange(len(b_words()))
#       4 x2 = [x + barwidth for x in x1]
#       5 x3 = [x + barwidth for x in x2]
#
# NameError: name 'b_words' is not defined

# %%
x_axis = decades

# %%
plt.bar(x_axis[0], bwords["All Out 50s"].sum(), width=barwidth, color = 'c', label = "B Words")
plt.bar(x_axis[0], fwords["All Out 50s"].sum(), width=barwidth, color = 'y', label = "F Words")
plt.bar(x_axis[0], swords["All Out 50s"].sum(), width=barwidth, color = 'b', label = "S Words")
plt.bar(x_axis[0], dwords["All Out 50s"].sum(), width=barwidth, color = 'g', label = "D Words")
plt.bar(x_axis[1], bwords["All Out 60s"].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[1], fwords["All Out 60s"].sum(), width=barwidth, color = 'y')
plt.bar(x_axis[1], swords["All Out 60s"].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[1], dwords["All Out 60s"].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[2], bwords["All Out 70s"].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[2], fwords["All Out 70s"].sum(), width=barwidth,  color = 'r')
plt.bar(x_axis[2], swords["All Out 70s"].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[2], dwords["All Out 70s"].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[3], bwords["All Out 80s"].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[3], fwords["All Out 80s"].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[3], swords["All Out 80s"].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[3], dwords["All Out 80s"].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[4], bwords["All Out 90s"].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[4], fwords["All Out 90s"].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[4], swords["All Out 90s"].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[4], dwords["All Out 90s"].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[5], bwords["All Out 00s"].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[5], fwords["All Out 00s"].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[5], swords["All Out 00s"].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[5], dwords["All Out 00s"].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[6], bwords["All Out 10s"].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[6], fwords["All Out 10s"].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[6], swords["All Out 10s"].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[6], dwords["All Out 10s"].sum(), width=barwidth, color = 'g')
plt.title("Use of Curse Words in Pop Music Lyrics from 1950s to 2010s")
plt.xlabel("Decades")
plt.ylabel("Number of Occurences")
plt.legend ()
plt.savefig("curses_over_decades.png")
plt.show()

# %%
df.columns
# Out:
# Index(['All Out 50s', 'All Out 60s', 'All Out 70s', 'All Out 80s',
#        'All Out 90s', 'All Out 00s', 'All Out 10s', 'US Top 50',
#        'Top_Male_Artists_of_2018', 'Top_Female_Artists_of_2018', 'Eminem',
#        'Beatles', 'Prince', 'Nina Simone', 'Lady Gaga', 'Justin Bieber',
#        'John Mayer', 'Depeche Mode', 'Ed Sheeran', 'Aretha Franklin',
#        'Ed Sheeran2', 'Adele', 'Tom Petty', 'Metallica', 'Madonna',
#        'Stevie Wonder', 'Earth Wind And Fire', 'Drake', 'Elton John',
#        'Radiohead', 'Kendrick_Lamar', 'Frank_Sinatra', 'Red Hot Chili Peppers',
#        'Michael Buble', 'Beyonce', 'John Legend', 'ACDC', 'All Playlists'],
#       dtype='object')

# %%
x_axis = ["Top Male Artists", "Top Female Artists"]

# %%
plt.bar(x_axis[0], bwords["Top_Male_Artists_of_2018"].sum(), color = 'c', label = "B Words")
plt.bar(x_axis[0], fwords["Top_Male_Artists_of_2018"].sum(), color = 'y', label = "F Words")
plt.bar(x_axis[0], swords["Top_Male_Artists_of_2018"].sum(), color = 'b', label = "S Words")
plt.bar(x_axis[0], dwords["Top_Male_Artists_of_2018"].sum(), color = 'g', label = "D Words")
plt.bar(x_axis[1], bwords["Top_Female_Artists_of_2018"].sum(), color = 'c')
plt.bar(x_axis[1], fwords["Top_Female_Artists_of_2018"].sum(), color = 'y')
plt.bar(x_axis[1], swords["Top_Female_Artists_of_2018"].sum(), color = 'b')
plt.bar(x_axis[1], dwords["Top_Female_Artists_of_2018"].sum(), color = 'g')
plt.title("Use of Curse Words in Pop Music Lyrics 2018: Male vs. Female Artists")
plt.xlabel("Playlists of Top Artists of 2018")
plt.ylabel("Number of Occurences")
plt.legend ()
plt.savefig("curses_male_vs_female.png")
plt.show()

# %%
df.columns
# Out:
# Index(['All Out 50s', 'All Out 60s', 'All Out 70s', 'All Out 80s',
#        'All Out 90s', 'All Out 00s', 'All Out 10s', 'US Top 50',
#        'Top_Male_Artists_of_2018', 'Top_Female_Artists_of_2018', 'Eminem',
#        'Beatles', 'Prince', 'Nina Simone', 'Lady Gaga', 'Justin Bieber',
#        'John Mayer', 'Depeche Mode', 'Ed Sheeran', 'Aretha Franklin',
#        'Ed Sheeran2', 'Adele', 'Tom Petty', 'Metallica', 'Madonna',
#        'Stevie Wonder', 'Earth Wind And Fire', 'Drake', 'Elton John',
#        'Radiohead', 'Kendrick_Lamar', 'Frank_Sinatra', 'Red Hot Chili Peppers',
#        'Michael Buble', 'Beyonce', 'John Legend', 'ACDC', 'All Playlists'],
#       dtype='object')

# %%
x_axis = ["Eminem", "Beatles",'Prince', 'Nina Simone', 'Lady Gaga', 'Justin Bieber',\
       'John Mayer', 'Depeche Mode', 'Ed Sheeran', 'Aretha Franklin', 'Adele', 'Tom Petty', 'Metallica', 'Madonna',\
       'Stevie Wonder', 'Earth Wind And Fire', 'Drake', 'Elton John',\
       'Radiohead', 'Kendrick Lamar', 'Frank Sinatra', 'Red Hot Chili Peppers',\
       'Michael Buble', 'Beyonce', 'John Legend', 'ACDC']

# %%
plt.bar(x_axis[25], bwords['ACDC'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[25], fwords['ACDC'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[25], swords['ACDC'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[25], dwords['ACDC'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[10], bwords['Adele'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[10], fwords['Adele'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[10], swords['Adele'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[10], dwords['Adele'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[9], bwords['Aretha Franklin'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[9], fwords['Aretha Franklin'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[9], swords['Aretha Franklin'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[9], dwords['Aretha Franklin'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[1], bwords["Beatles"].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[1], fwords["Beatles"].sum(), width=barwidth, color = 'y')
plt.bar(x_axis[1], swords["Beatles"].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[1], dwords["Beatles"].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[23], bwords['Beyonce'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[23], fwords['Beyonce'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[23], swords['Beyonce'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[23], dwords['Beyonce'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[7], bwords['Depeche Mode'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[7], fwords['Depeche Mode'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[7], swords['Depeche Mode'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[7], dwords['Depeche Mode'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[16], bwords['Drake'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[16], fwords['Drake'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[16], swords['Drake'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[16], dwords['Drake'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[15], bwords['Earth Wind And Fire'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[15], fwords['Earth Wind And Fire'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[15], swords['Earth Wind And Fire'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[15], dwords['Earth Wind And Fire'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[8], bwords['Ed Sheeran'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[8], fwords['Ed Sheeran'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[8], swords['Ed Sheeran'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[8], dwords['Ed Sheeran'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[8], bwords['Ed Sheeran2'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[8], fwords['Ed Sheeran2'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[8], swords['Ed Sheeran2'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[8], dwords['Ed Sheeran2'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[17], bwords['Elton John'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[17], fwords['Elton John'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[17], swords['Elton John'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[17], dwords['Elton John'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[0], bwords["Eminem"].sum(), width=barwidth, color = 'c', label = "B Words")
plt.bar(x_axis[0], fwords["Eminem"].sum(), width=barwidth, color = 'y', label = "F Words")
plt.bar(x_axis[0], swords["Eminem"].sum(), width=barwidth, color = 'b', label = "S Words")
plt.bar(x_axis[0], dwords["Eminem"].sum(), width=barwidth, color = 'g', label = "D Words")

plt.bar(x_axis[20], bwords['Frank_Sinatra'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[20], fwords['Frank_Sinatra'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[20], swords['Frank_Sinatra'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[20], dwords['Frank_Sinatra'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[24], bwords['John Legend'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[24], fwords['John Legend'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[24], swords['John Legend'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[24], dwords['John Legend'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[6], bwords['John Mayer'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[6], fwords['John Mayer'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[6], swords['John Mayer'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[6], dwords['John Mayer'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[5], bwords['Justin Bieber'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[5], fwords['Justin Bieber'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[5], swords['Justin Bieber'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[5], dwords['Justin Bieber'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[19], bwords['Kendrick_Lamar'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[19], fwords['Kendrick_Lamar'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[19], swords['Kendrick_Lamar'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[19], dwords['Kendrick_Lamar'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[4], bwords['Lady Gaga'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[4], fwords['Lady Gaga'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[4], swords['Lady Gaga'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[4], dwords['Lady Gaga'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[13], bwords['Madonna'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[13], fwords['Madonna'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[13], swords['Madonna'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[13], dwords['Madonna'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[12], bwords['Metallica'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[12], fwords['Metallica'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[12], swords['Metallica'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[12], dwords['Metallica'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[22], bwords['Michael Buble'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[22], fwords['Michael Buble'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[22], swords['Michael Buble'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[22], dwords['Michael Buble'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[3], bwords['Nina Simone'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[3], fwords['Nina Simone'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[3], swords['Nina Simone'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[3], dwords['Nina Simone'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[2], bwords['Prince'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[2], fwords['Prince'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[2], swords['Prince'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[2], dwords['Prince'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[18], bwords['Radiohead'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[18], fwords['Radiohead'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[18], swords['Radiohead'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[18], dwords['Radiohead'].sum(), width=barwidth, color = 'g')
plt.bar(x_axis[21], bwords['Red Hot Chili Peppers'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[21], fwords['Red Hot Chili Peppers'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[21], swords['Red Hot Chili Peppers'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[21], dwords['Red Hot Chili Peppers'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[14], bwords['Stevie Wonder'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[14], fwords['Stevie Wonder'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[14], swords['Stevie Wonder'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[14], dwords['Stevie Wonder'].sum(), width=barwidth, color = 'g')

plt.bar(x_axis[11], bwords['Tom Petty'].sum(), width=barwidth, color = 'c')
plt.bar(x_axis[11], fwords['Tom Petty'].sum(), width=barwidth,  color = 'y')
plt.bar(x_axis[11], swords['Tom Petty'].sum(), width=barwidth, color = 'b')
plt.bar(x_axis[11], dwords['Tom Petty'].sum(), width=barwidth, color = 'g')

plt.xticks(x_axis, rotation = 'vertical')
plt.title("Curse Words Used in Lyrics by Popular Artists")
plt.xlabel("Artists")
plt.ylabel("Number of Occurences")
plt.legend ()
plt.savefig("curses_artists_ind.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-7bc457cfa9ec> in <module>
#     126 plt.ylabel("Number of Occurences")
#     127 plt.legend ()
# --> 128 plt.savefig.bbox("curses_artists_ind.png")
#     129 plt.show()
#
# AttributeError: 'function' object has no attribute 'bbox'
