# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_path="./results.csv"
df=pd.read_csv(csv_path)

# %%
df.reset_index()
# Out:
#        index       Column1  All Out 50s  All Out 60s  All Out 70s  \
# 0          0             i        162.0        244.0        459.0
# 1          1           you        150.0        244.0        298.0
# 2          2           the        155.0        324.0        561.0
# 3          3             a         81.0        176.0        347.0
# 4          4            my         64.0         96.0        236.0
# 5          5            me         67.0        154.0        230.0
# 6          6            it         39.0         65.0        119.0
# 7          7           i'm         14.0         72.0        139.0
# 8          8            to         67.0        149.0        269.0
# 9          9           and        117.0        198.0        395.0
# 10        10          yeah         16.0         33.0         38.0
# 11        11          that         52.0         71.0        129.0
# 12        12            on         35.0         77.0        105.0
# ...

# %%
df = df.set_index("Column1")

# %%
df = df.fillna(value = 0)

# %%
bwords=[]
fwords=[]
swords=[]
dwords=[]
for items in list(df.index.values): 
    if "bitch" in items: 
        bwords.append(items)
    if "fuck" in items:
        fwords.append(items)
    if "shit" in items:
        swords.append(items)
    if "dick" in items:
        dwords.append(items)
print(bwords)
print(fwords)
print(swords)
print(dwords)
# Out:
# ['bitch', 'bitches', 'bitch!', 'bitching', 'fuk.a.bitch', 'bitchin’', 'bitch-ass']
# ['fuck', "fuckin'", 'fucking', 'fucked', "fuckin'—", 'fucking—', 'motherfucker', 'morherfuckin', 'fucker', 'fucks', 'motherfucking', 'fuckin', 'mothafucker', 'fucked—other', "motherfuckin'", 'motherfuckin’', 'mothafucka!"', 'fuckers', 'motherfuckin', 'motherfuckers', "mothafuckin'", 'motherfuckerss', 'f-f-fuck', 'mothafucka']
# ['shit', "shit's", 'shits', 'shitty', 'bullshit"', 'shit?', 'bullshit', 'shit"', 'bullshit!', 'shitting', 'shit!', 'shit.']
# ['dick', 'dicked', 'dick!', 'dick?']

# %%
bwords=df.loc[bwords]
fwords=df.loc[fwords]
swords=df.loc[swords]
dwords=df.loc[dwords]

# %%
df.columns
# Out:
# Index(['All Out 50s', 'All Out 60s', 'All Out 70s', 'All Out 80s',
#        'All Out 90s', 'All Out 00s', 'All Out 10s', 'US Top 50',
#        'Top_Male_Artists_of_2018', 'Top_Female_Artists_of_2018', 'Eminem',
#        'Beatles', 'Prince', 'Nina Simone', 'Lady Gaga', 'Justin Bieber',
#        'John Mayer', 'Depeche Mode', 'Ed Sheeran', 'Aretha Franklin',
#        'Ed Sheeran2', 'Adele', 'Tom Petty', 'Metallica', 'Madonna',
#        'Stevie Wonder', 'Earth Wind And Fire', 'Drake', 'Elton John',
#        'Radiohead', 'Kendrick_Lamar', 'Frank_Sinatra', 'Red Hot Chili Peppers',
#        'Michael Buble', 'Beyonce', 'John Legend', 'ACDC', 'All Playlists'],
#       dtype='object')

# %%
b_all = bwords["All Playlists"].sum()
f_all = fwords["All Playlists"].sum()
s_all = swords["All Playlists"].sum()
d_all = dwords["All Playlists"].sum()
b_all
decades=["1950s", "1960s", "1970s", "1980s", "1990s", "2000s", "2010s", "All Playlists"]

# %%
barwidth=0.25

x1 = np.arange(len(b_words()))
x2 = [x + barwidth for x in x1]
x3 = [x + barwidth for x in x2]
x4 = [x + barwidth for x in x3]
print(x1)
print(x2)
print(x3)
print(x4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fd9ed58c9d33> in <module>
#       1 barwidth=0.25
#       2
# ----> 3 x1 = np.arange(len(b_words()))
#       4 x2 = [x + barwidth for x in x1]
#       5 x3 = [x + barwidth for x in x2]
#
# NameError: name 'b_words' is not defined

# %%
x_axis = decades

# %%
plt.bar(x_axis[0], bwords["All Out 50s"], width=barwidth, color = 'c', label = "B Words")
plt.bar(x_axis[0], fwords["All Out 50s"], width=barwidth, color = 'r', label = "F Words")
plt.bar(x_axis[0], swords["All Out 50s"], width=barwidth, color = 'b', label = "S Words")
plt.bar(x_axis[0], dwords["All Out 50s"], width=barwidth, color = 'g', label = "D Words")
plt.bar(x_axis[1], bwords["All Out 60s"], width=barwidth, color = 'c')
plt.bar(x_axis[1], fwords["All Out 60s"], width=barwidth, color = 'r')
plt.bar(x_axis[1], swords["All Out 60s"], width=barwidth, color = 'b')
plt.bar(x_axis[1], dwords["All Out 60s"], width=barwidth, color = 'g')
plt.bar(x_axis[2], bwords["All Out 70s"], width=barwidth, color = 'c')
plt.bar(x_axis[2], fwords["All Out 70s"], width=barwidth,  color = 'r')
plt.bar(x_axis[2], swords["All Out 70s"], width=barwidth, color = 'b')
plt.bar(x_axis[2], dwords["All Out 70s"], width=barwidth, color = 'g')
plt.bar(x_axis[3], bwords["All Out 80s"], width=barwidth, color = 'c')
plt.bar(x_axis[3], fwords["All Out 80s"], width=barwidth,  color = 'r')
plt.bar(x_axis[3], swords["All Out 80s"], width=barwidth, color = 'b')
plt.bar(x_axis[3], dwords["All Out 80s"], width=barwidth, color = 'g')
plt.bar(x_axis[4], bwords["All Out 90s"], width=barwidth, color = 'c')
plt.bar(x_axis[4], fwords["All Out 90s"], width=barwidth,  color = 'r')
plt.bar(x_axis[4], swords["All Out 90s"], width=barwidth, color = 'b')
plt.bar(x_axis[4], dwords["All Out 90s"], width=barwidth, color = 'g')
plt.bar(x_axis[5], bwords["All Out 00s"], width=barwidth, color = 'c')
plt.bar(x_axis[5], fwords["All Out 00s"], width=barwidth,  color = 'r')
plt.bar(x_axis[5], swords["All Out 00s"], width=barwidth, color = 'b')
plt.bar(x_axis[5], dwords["All Out 00s"], width=barwidth, color = 'g')
plt.bar(x_axis[6], bwords["All Out 10s"], width=barwidth, color = 'c')
plt.bar(x_axis[6], fwords["All Out 10s"], width=barwidth,  color = 'r')
plt.bar(x_axis[6], swords["All Out 10s"], width=barwidth, color = 'b')
plt.bar(x_axis[6], dwords["All Out 10s"], width=barwidth, color = 'g')
plt.legend ()
