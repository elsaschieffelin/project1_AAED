# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_path5 = "lyrics_output/df_words_All_Out_50s.csv"
csv_path6 = "lyrics_output/df_words_All_Out_60s.csv"
csv_path7 = "lyrics_output/df_words_All_Out_70s.csv"
csv_path8 = "lyrics_output/df_words_All_Out_80s.csv"

# %%
df_50s = pd.read_csv(csv_path5)
df_60s = pd.read_csv(csv_path6)
df_70s = pd.read_csv(csv_path7)
df_80s = pd.read_csv(csv_path8)

# %%
df_50s = df_50s.sort_values("count", ascending = False).reset_index()

# %%
df_50s = df_50s.rename(columns = {"Unnamed: 0": "words"})

# %%
df_50s_sample = df_50s.head(51)

# %%
df_50s_sample
# Out:
#         words  index  count
# 0         the     18    180
# 1           i     15    162
# 2         you     21    149
# 3         and     46    119
# 4           a     95     84
# 5          to    209     67
# 6          me      9     63
# 7          in    127     58
# 8          my     25     57
# 9        love     37     52
# 10       that      6     52
# 11         of     13     46
# 12        all    206     40
# 13         it      3     39
# 14       your     83     37
# 15         be    100     36
# 16         on     41     36
# 17        yes     59     36
# 18      don't      1     35
# 19         is     97     35
# 20      tweet    690     35
# 21        but     57     34
# 22       know     38     31
# 23       it's    157     31
# 24        out    101     29
# 25       when     75     28
# 26      dream    203     27
# 27        can    117     26
# 28       this    179     26
# 29       what     34     24
# 30        are    160     24
# 31      verse     73     23
# ...

# %%
words_50 = df_50s_sample["words"]
x_axis = np.arange(len(words_50))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, df_50s_sample['count'], color='r', alpha=0.5, align='center')
plt.xticks(tick_locations, words_50, rotation='vertical')
plt.title("Top 50 words in 1950s' Top Songs")
plt.savefig("50_top_words_1950s.png")
plt.show()

# %%
df_60s=df_60s.sort_values("count", ascending = False)

# %%
df_60s = df_60s.rename(columns={"Unnamed: 0": "words"})

# %%
df_60s_sample = df_60s.head(50)

# %%
words_50 = df_60s_sample["words"]
x_axis = np.arange(len(words_50))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, df_60s_sample['count'], color='r', alpha=0.5, align='center')
plt.xticks(tick_locations, words_50, rotation='vertical')
plt.title("Top 50 words in 1960s' Top Songs")
plt.savefig("50_top_words_1960s.png")
plt.show()

# %%
df_70s = df_70s.sort_values("count", ascending = False)
df_70s = df_70s.rename(columns = {"Unnamed: 0": "words"})
df_70s_sample = df_70s.head(50)

# %%
words_50 = df_70s_sample["words"]
x_axis = np.arange(len(words_50))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, df_70s_sample['count'], color='r', alpha=0.5, align='center')
plt.xticks(tick_locations, words_50, rotation='vertical')
plt.title("Top 50 words in 1970s' Top Songs")
plt.savefig("50_top_words_1970s.png")
plt.show()

# %%
df_80s = df_80s.sort_values("count", ascending = False)
df_80s = df_80s.rename(columns = {"Unnamed: 0": "words"})
df_80s_sample = df_80s.head(50)

# %%
words_50 = df_80s_sample["words"]
x_axis = np.arange(len(words_50))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, df_80s_sample['count'], color='r', alpha=0.5, align='center')
plt.xticks(tick_locations, words_50, rotation='vertical')
plt.title("Top 50 words in 1980s' Top Songs")
plt.savefig("50_top_words_1980s.png")
plt.show()
