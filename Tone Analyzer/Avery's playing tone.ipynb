# %%
import spotipy
import pandas as pd
from pprint import pprint
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import spotipy.oauth2 as oauth2
from bs4 import BeautifulSoup
from config import genius_api_key, spotify_elsa_id, spotify_elsa_secret
import matplotlib.pyplot as plt
import numpy as np
import csv


### create functions

def request_song_info(song_title, artist_name):
    main_url = 'https://api.genius.com/search'
    headers = {'Authorization': 'Bearer ' + genius_api_key}
    data = {'q': song + ' ' + artist}
    response = requests.get(main_url, data=data, headers=headers)

    return response

def get_song_lyrics(url):
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    lyrics = html.find('div', class_='lyrics').get_text()
    return lyrics

# def word_count(str):
#     counts = dict()
#     words = str.split()

#     for word in words:
#         if word in counts:
#             counts[word] += 1
#         else:
#             counts[word] = 1

#     return counts

def numList(list):
        dic = {}
        for num in list:
            if num in dic.keys():
                dic[num] += 1
            else:       
                key = num
                value = 1
                dic[key] = value
        return dic

def call_playlists (user_id_str, playlist_id_str, offset_value):
    playlists=sp.user_playlist_tracks(user=user_id_str,playlist_id=playlist_id_str, offset=offset_value, limit=100)
    return playlists

##Set Spotify API tokens
credentials = oauth2.SpotifyClientCredentials(
       client_id=spotify_elsa_id,
       client_secret=spotify_elsa_secret)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)
sp = spotipy.Spotify(auth=token)

# %%
# playlist_dict[pl][user_id_str]
# playlist_dict[pl][playlist_id_str]
# playlist_dict[pl][playlist_len]
# playist_dict[pl][playlist_title]

playlist_dicta={
    1:{"user_id_str": "nxuzwr3ncg3ks6f1iy1grrrvc","playlist_id_str":"356RdloI1Y4ozLdUTh0FAU", "playlist_len": 101,"playlist_title":"United_States_Top_50"},
    2:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWSV3Tk4GO2fq","playlist_len": 75, "playlist_title":"All_Out_50s"},
    3:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXaKIA8E7WcJj","playlist_len": 97, "playlist_title":"All_Out_60s"}, 
    4:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWTJ7xPn4vNaz","playlist_len": 104, "playlist_title":"All_Out_70s"},
    5:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX4UtSsGT1Sbe","playlist_len": 100, "playlist_title":"All_Out_80s"},
    6:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXbTxeAdrVG2l","playlist_len": 90, "playlist_title":"All_Out_90s"},
    7:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX4o1oenSJRJd","playlist_len": 100, "playlist_title":"All_Out_00s"},
    8:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX5Ejj0EkURtP","playlist_len": 100,"playlist_title":"All_Out_10s"},
    9:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWSsIr3Vjy37l","playlist_len": 50,"playlist_title":"Top_Male_Artists_of_2018"},
    10:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX82tVoNhkbcO","playlist_len": 50,"playlist_title":"Top_Female_Artists_of_2018"},
    11:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX1clOuib1KtQ","playlist_len": 68,"playlist_title":"This_Is_Eminem"},
    12:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXdLtD0qszB1w","playlist_len": 90,"playlist_title":"This_Is_The_Beatles"},
    13:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX6JzJ8vAK836","playlist_len": 73,"playlist_title":"This_Is_Prince"},
    14:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX8OYzU0lx5hL","playlist_len": 50,"playlist_title":"This_Is_Nina_Simone"},
    15:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXc7FZ2VBjaeT","playlist_len": 41,"playlist_title":"This_Is_Lady_Gaga"},
    16:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXc2aPBXGmXrt","playlist_len": 50,"playlist_title":"This_Is_Justin_Bieber"},
    17:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWYrlaUEYy4Vg","playlist_len": 63,"playlist_title":"This_Is_John_Mayer"},
    18:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX3BSwupE5hR7","playlist_len": 51,"playlist_title":"This_Is_Depeche_Mode"},
    19:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWWxPM4nWdhyI","playlist_len": 34,"playlist_title":"This_Is_Ed_Sheeran"},
    20:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX6bJVMtDYJHx","playlist_len": 51,"playlist_title":"This_Is_Aretha_Franklin"},
    21:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWZUozJiHy44Y","playlist_len": 25,"playlist_title":"This_Is_Adele"},
    22:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWUlZhYdX0uqM","playlist_len": 55,"playlist_title":"This_Is_Tom_Petty"},
    23:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXbj9Ksq4BAdj","playlist_len": 72,"playlist_title":"This_Is_Metallica"},
    24:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWTQllLRMgY9S","playlist_len": 50,"playlist_title":"This_Is_Madonna"},
    25:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWWYIyS8LLUDj","playlist_len": 50,"playlist_title":"This_Is_Stevie_Wonder"},
    26:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX3yvjXSVJwJV","playlist_len": 24,"playlist_title":"This_Is_Earth_Wind_And_Fire"},
    27:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX7QOv5kjbU68","playlist_len": 66,"playlist_title":"This_Is_Drake"},
    28:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX7VulteLVOkq","playlist_len": 43,"playlist_title":"This_Is_Elton_John"},
    29:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX1XDyq5cTk95","playlist_len": 50,"playlist_title":"This_Is_Radiohead"},
    30:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX5EkyRFIV92g","playlist_len": 39,"playlist_title":"This_Is_Kendrick_Lamar"},
    31:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX4H3NUOwVLXj","playlist_len": 50,"playlist_title":"This_Is_Frank_Sinatra"},
    32:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXbuvTm9NMIGt","playlist_len": 50,"playlist_title":"This_Is_Red_Hot_Chili_Peppers"},
    33:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX5kVmFQxhnLW","playlist_len": 50,"playlist_title":"This_Is_Michael_Buble"},
    34:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX2oU49YwtXI2","playlist_len": 34,"playlist_title":"This_Is_Beyonce"},
    35:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX8DxW4iib3Eq","playlist_len": 37,"playlist_title":"This_Is_John_Legend"},
    36:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXec50AjHrNTq","playlist_len": 36,"playlist_title":"This_Is_ACDC"}

     }

# %%
playlist_dict={1:{"user_id_str": "nxuzwr3ncg3ks6f1iy1grrrvc","playlist_id_str":"356RdloI1Y4ozLdUTh0FAU", "playlist_len": 101,"playlist_title":"United_States_Top_50"}}
playlist_dict2={2:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWSV3Tk4GO2fq","playlist_len": 75, "playlist_title":"All_Out_50s"}}
playlist_dict3={3:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXaKIA8E7WcJj","playlist_len": 97, "playlist_title":"All_Out_60s"}}
playlist_dict4={4:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DWTJ7xPn4vNaz","playlist_len": 104, "playlist_title":"All_Out_70s"}}
playlist_dict5={5:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX4UtSsGT1Sbe","playlist_len": 100, "playlist_title":"All_Out_80s"}}
playlist_dict6={6:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DXbTxeAdrVG2l","playlist_len": 90, "playlist_title":"All_Out_90s"}}
playlist_dict7={7:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX4o1oenSJRJd","playlist_len": 100, "playlist_title":"All_Out_00s"}}
playlist_dict8={8:{"user_id_str": "spotify","playlist_id_str":"37i9dQZF1DX5Ejj0EkURtP","playlist_len": 100,"playlist_title":"All_Out_10s"}}

# %%
##Set empty lists to use later
pl=1
gbl = globals()
dataframes=[]
for item in playlist_dict:
    song_titles_list=[]
    artist_names_list=[]
    list_of_ids=[]
    tracks_top=[]
    words_collected=[]
    sep_words=[]
    full_list=[]
    song_titles_list[:] = []
    artist_names_list[:] = []
    list_of_ids[:] = []
    tracks_top[:] =[]
    words_collected[:] = []
    sep_words[:] = []
    full_list[:] = []
    song_titles_list=[]
    artist_names_list=[]
    list_of_ids=[]
    tracks_top=[]
    words_collected=[]
    sep_words=[]
    full_list=[]

    offset_value=0
    x=0
    
    user_id_str=playlist_dict[pl]["user_id_str"]
    playlist_id_str=playlist_dict[pl]["playlist_id_str"]
    playlist_len=playlist_dict[pl]["playlist_len"]
    playlist_title=playlist_dict[pl]["playlist_title"]
    try:
        while len(artist_names_list) <= playlist_len:
            offset_value=0
            playlists=call_playlists(user_id_str, playlist_id_str,offset_value)
            artist_name=playlists["items"][x]['track']['artists'][0]['name']
            song_name=playlists["items"][x]['track']['album']['name']
            song_id=playlists["items"][x]['track']['id']
            if song_id not in list_of_ids:
                artist_names_list.append(artist_name)
                song_titles_list.append(song_name)
                list_of_ids.append(song_id)
                x+=1
                offset_value=len(artist_names_list)
                call_playlists(user_id_str, playlist_id_str, offset_value)
            else:
                x+=1
    except IndexError:
        print(f"You've saved {len(artist_names_list)} songs for the {playlist_title} playlist")
# Out:
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-968c0eaee1be> in <module>
#      36         while len(artist_names_list) <= playlist_len:
#      37             offset_value=0
# ...

# %%
x=0
df=[]
decades = ["1950s", "1960s", "1970s", "1980s", "1990s", "2000s", "2010s", "US_Top_50"]
for decade in decades: 
    decade = decades[x]
    path = f"decade_output/{decade}.csv"
    df.append(pd.read_csv(path))
    x+=1

# %%
df5 = df[0]
df6 = df[1]
df7 = df[2]
df8 = df[3]
df9 = df[4]
df0 = df[5]
df1 = df[6]
dfu = df[7]

# %%
x=0
sldf=[]
aldf=[]
for x in range(0,8):
    dfs=df[x]
    s=dfs['song_title'].str.lower()
    a=dfs['artist_name'].str.lower()
    sldf.append(s)
    aldf.append(a)
    x+=1

# %%
s=list(sldf)
a=list(aldf)
for x in range(0,8):
#

# %%
d = list(zip(sldf[0],aldf[0]))
x=0
tracks_top=[]
for items in d:
    artist=aldf[x]
    song=sldf[x]
    song_dict={"song_title":song, "artist_name":artist}
    tracks_top.append(song_dict)
    x+=1

x=0
words_collected=[]
for item in tracks_top:
    song_title=tracks_top[x]['song_title']
    artist_name=tracks_top[x]['artist_name']
    request_song_info(song_title, artist_name).text

    response = request_song_info(song_title, artist_name)
    data = response.json()
    remote_song_info = None

    for hit in data['response']['hits']:
        if artist_name in hit['result']['primary_artist']['name'].lower():
            remote_song_info = hit
            break

    if remote_song_info:
        try:
            song_url = remote_song_info['result']['url']

            clean_lyrics=get_song_lyrics(song_url).replace("\n"," ")
            clean_lyrics=clean_lyrics.replace("[","")
            clean_lyrics=clean_lyrics.replace("]","")
            clean_lyrics=clean_lyrics.replace(":","")
            clean_lyrics=clean_lyrics.replace("  "," ")
            clean_lyrics=clean_lyrics.replace("(","")
            clean_lyrics=clean_lyrics.replace(")","")
            clean_lyrics=clean_lyrics.replace("&","")
            clean_lyrics=clean_lyrics.replace(",","")
            clean_lyrics=clean_lyrics.replace("\ ","")
            clean_lyrics=clean_lyrics.replace("\'","")
            clean_lyrics=clean_lyrics.replace("?","")
            clean_lyrics=clean_lyrics.replace("!","")
            clean_lyrics=clean_lyrics.replace('"',"")
            clean_lyrics=clean_lyrics.replace("'","")
            clean_lyrics=clean_lyrics.lower()
            words_collected.append(clean_lyrics)
        except AttributeError:
            continue
    x+=1
print(f"You've successfully scraped lyrics for {len(words_collected)} out of {len(artist_names_list)} songs in the {playlist_title} playlist")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-332-502a3de901c2> in <module>
#      22
#      23     for hit in data['response']['hits']:
# ---> 24         if artist_name in hit['result']['primary_artist']['name'].lower():
#      25             remote_song_info = hit
#      26             break
#
# TypeError: 'in <string>' requires string as left operand, not Series

# %%
d = list(zip(s,a))
# x=0
# s0=s[0]
# a0=a[0]
# d0=list(zip(s,a))

# %%
x=0
y=0
tracks_top=[]
for items in d:
    artist=a[x]
    song=s[x]
    song_dict={"song_title":song, "artist_name":artist}
    tracks_top.append(song_dict)
    x+=1
tracks_top
# Out:
# [{'song_title': 0                         the definitive 60's (sixties)
#   1                                  don't play that song
#   2                              the ultimate bobby darin
#   3                                   under the boardwalk
#   4                             the definitive collection
#   5                      fabulous fifties nostalgia vol 5
#   6                           the temptations sing smokey
#   7                          the legendary masters series
#   8                 greatest hits: walking to new orleans
#   9                                     the reprise years
#   10                  "all i do is dream" everly brothers
#   11                                          collections
#   12                                           that's all
#   13                                   fats domino swings
#   14                                               doogal
#   15                 the very best of the everly brothers
# ...

# %%
# x=0
# words_collected=[]
# for item in tracks_top:
#     songs=tracks_top[x]['song_title']
#     artists=tracks_top[x]['artist_name']
#     plays=[]
#     y=0
#     for item in tracks_top:
#         song=songs[y]
#         artist=artists[y]
#         y+=1
#     request_song_info(song, artist).text


#     response = request_song_info(song, artist)
#     data = response.json()
#     remote_song_info = None
x=0
words_collected=[]
for item in tracks_top:
    song_title=tracks_top[x]['song_title'].lower()
    artist_name=tracks_top[x]['artist_name'].lower()
    request_song_info(song_title, artist_name).text

    response = request_song_info(song_title, artist_name)
    data = response.json()
    remote_song_info = None

    for hit in data['response']['hits']:
        if artist.lower() in hit['result']['primary_artist']['name'].lower():
            remote_song_info = hit
            break

    if remote_song_info:
        try:
            song_url = remote_song_info['result']['url']

            clean_lyrics=get_song_lyrics(song_url).replace("\n"," ")
            clean_lyrics=clean_lyrics.replace("[","")
            clean_lyrics=clean_lyrics.replace("]","")
            clean_lyrics=clean_lyrics.replace(":","")
            clean_lyrics=clean_lyrics.replace("  "," ")
            clean_lyrics=clean_lyrics.replace("(","")
            clean_lyrics=clean_lyrics.replace(")","")
            clean_lyrics=clean_lyrics.replace("&","")
            clean_lyrics=clean_lyrics.replace(",","")
            clean_lyrics=clean_lyrics.replace("\ ","")
            clean_lyrics=clean_lyrics.replace("\'","")
            clean_lyrics=clean_lyrics.replace("?","")
            clean_lyrics=clean_lyrics.replace("!","")
            clean_lyrics=clean_lyrics.replace('"',"")
            clean_lyrics=clean_lyrics.replace("'","")
            clean_lyrics=clean_lyrics.replace("verse 1","")
            clean_lyrics=clean_lyrics.replace("verse 2","")
            clean_lyrics=clean_lyrics.replace("pre-chorus","")
            clean_lyrics=clean_lyrics.replace("intro","")
            clean_lyrics=clean_lyrics.replace("chorus","")
            clean_lyrics=clean_lyrics.lower()
            words_collected.append(clean_lyrics)
        except AttributeError:
            continue
    x+=1
print(f"You've successfully scraped lyrics for {len(words_collected)} out of {len(artist_names_list)} songs in the {playlist_title} playlist")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-310-92d8548b4688> in <module>
#      19 words_collected=[]
#      20 for item in tracks_top:
# ---> 21     song_title=tracks_top[x]['song_title'].lower()
#      22     artist_name=tracks_top[x]['artist_name'].lower()
#      23     request_song_info(song_title, artist_name).text
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
x=0
words_collected=[]
for item in tracks_top:
    songs=list(tracks_top[x]['song_title'])
    artists=list(tracks_top[x]['artist_name'])
    y=0
    for item in songs:
        song=songs[y]
        y+=0
    for item in artists:
        artist=artists[y]
        y+=0
    request_song_info(song, artist).text

    response = request_song_info(song, artist)
    data = response.json()
    remote_song_info = None

    for hit in data['response']['hits']:
        if artist in hit['result']['primary_artist']['name'].lower():
            remote_song_info = hit
            break

    if remote_song_info:
        try:
            song_url = remote_song_info['result']['url']

            clean_lyrics=get_song_lyrics(song_url).replace("\n"," ")
            clean_lyrics=clean_lyrics.replace("[","")
            clean_lyrics=clean_lyrics.replace("]","")
            clean_lyrics=clean_lyrics.replace(":","")
            clean_lyrics=clean_lyrics.replace("  "," ")
            clean_lyrics=clean_lyrics.replace("(","")
            clean_lyrics=clean_lyrics.replace(")","")
            clean_lyrics=clean_lyrics.replace("&","")
            clean_lyrics=clean_lyrics.replace(",","")
            clean_lyrics=clean_lyrics.replace("\ ","")
            clean_lyrics=clean_lyrics.replace("\'","")
            clean_lyrics=clean_lyrics.replace("?","")
            clean_lyrics=clean_lyrics.replace("!","")
            clean_lyrics=clean_lyrics.replace('"',"")
            clean_lyrics=clean_lyrics.replace("'","")
            clean_lyrics=clean_lyrics.replace("verse 1","")
            clean_lyrics=clean_lyrics.replace("verse 2","")
            clean_lyrics=clean_lyrics.replace("pre-chorus","")
            clean_lyrics=clean_lyrics.replace("intro","")
            clean_lyrics=clean_lyrics.replace("chorus","")
            clean_lyrics=clean_lyrics.lower()
            words_collected.append(clean_lyrics)
        except AttributeError:
            continue
    x+=1
print(f"You've successfully scraped lyrics for {len(words_collected)} out of {len(artist_names_list)} songs in the {playlist_title} playlist")
# Out:
# You've successfully scraped lyrics for 4 out of 3 songs in the United_States_Top_50 playlist

# %%
# %whos DataFrame
words_collected
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# dd         DataFrame        Unnamed: 0           <...>\n\n[68 rows x 4 columns]
# df0        DataFrame        Unnamed: 0           <...>\n\n[88 rows x 4 columns]
# df1        DataFrame        Unnamed: 0           <...>\n\n[88 rows x 4 columns]
# df5        DataFrame        Unnamed: 0           <...>\n\n[68 rows x 4 columns]
# df6        DataFrame        Unnamed: 0           <...>\n\n[91 rows x 4 columns]
# df7        DataFrame        Unnamed: 0           <...>\n\n[93 rows x 4 columns]
# df8        DataFrame        Unnamed: 0           <...>\n\n[97 rows x 4 columns]
# df9        DataFrame        Unnamed: 0           <...>\n\n[82 rows x 4 columns]
# df_00      DataFrame        Unnamed: 0           <...>\n\n[88 rows x 4 columns]
# df_10      DataFrame        Unnamed: 0           <...>\n\n[88 rows x 4 columns]
# df_50      DataFrame        Unnamed: 0           <...>\n\n[68 rows x 4 columns]
# ...

# %%
output_data = "TopUSlyrics.txt"
with open (output_data,'w') as file: 
       file.write(str(words_collected))

# %%
playlist_avg_per_song={
    "df_words_United_States_Top_50":df_words_United_States_Top_50.count()/52,
    "df_words_All_Out_50s": df_words_All_Out_50s.count()/22,
    "df_words_All_Out_60s": df_words_All_Out_60s.count()/40,
    "df_words_All_Out_70s": df_words_All_Out_70s.count()/55,
    "df_words_All_Out_80s": df_words_All_Out_80s.count()/45,
    "df_words_All_Out_90s": df_words_All_Out_90s.count()/53,
    "df_words_All_Out_00s": df_words_All_Out_00s.count()/66,
    "df_words_All_Out_10s": df_words_All_Out_10s.count()/68,
    "df_words_Top_Male_Artists_of_2018": df_words_Top_Male_Artists_of_2018.count()/33,
    "df_words_Top_Female_Artists_of_2018": df_words_Top_Female_Artists_of_2018.count()/34,
    "df_words_This_Is_Eminem": df_words_This_Is_Eminem.count()/43,
    "df_words_This_Is_The_Beatles": df_words_This_Is_The_Beatles.count()/29,
    "df_words_This_Is_Prince": df_words_This_Is_Prince.count()/58,
    "df_words_This_Is_Nina_Simone": df_words_This_Is_Nina_Simone.count()/31, 
    "df_words_This_Is_Lady_Gaga": df_words_This_Is_Lady_Gaga.count()/28, 
    "df_words_This_Is_Justin_Bieber": df_words_This_Is_Justin_Bieber.count()/38, 
    "df_words_This_Is_John_Mayer": df_words_This_Is_John_Mayer.count()/32, 
    "df_words_This_Is_Depeche_Mode": df_words_This_Is_Depeche_Mode.count()/13, 
    "df_words_This_Is_Ed_Sheeran": df_words_This_Is_Ed_Sheeran.count()/31, 
    "df_words_This_Is_Aretha_Franklin": df_words_This_Is_Aretha_Franklin.count()/33, 
    "df_words_This_Is_Adele": df_words_This_Is_Adele.count()/25 ,
    "df_words_This_Is_Tom_Petty": df_words_This_Is_Tom_Petty.count()/42 ,
    "df_words_This_Is_Metallica": df_words_This_Is_Metallica.count()/50 ,
    "df_words_This_Is_Madonna": df_words_This_Is_Madonna.count()/17 ,
    "df_words_This_Is_Stevie_Wonder": df_words_This_Is_Stevie_Wonder.count()/19 ,
    "df_words_This_Is_Earth_Wind_And_Fire": df_words_This_Is_Earth_Wind_And_Fire.count()/12 ,
    "df_words_This_Is_Drake": df_words_This_Is_Drake.count()/12 ,
    "df_words_This_Is_Elton_John": df_words_This_Is_Elton_John.count()/14 ,
    "df_words_This_Is_Radiohead": df_words_This_Is_Radiohead.count()/42 ,
    "df_words_This_Is_Kendrick_Lamar": df_words_This_Is_Kendrick_Lamar.count()/33,
    "df_words_This_Is_Frank_Sinatra": df_words_This_Is_Frank_Sinatra.count()/19,
    "df_words_This_Is_Red_Hot_Chili_Peppers": df_words_This_Is_Red_Hot_Chili_Peppers.count()/29,
    "df_words_This_Is_Michael_Buble": df_words_This_Is_Michael_Buble.count()/20,
    "df_words_This_Is_Beyonce": df_words_This_Is_Beyonce.count()/26,
    "df_words_This_Is_John_Legend": df_words_This_Is_John_Legend.count()/27,
    "df_words_This_Is_ACDC": df_words_This_Is_ACDC.count()/21,    
}

artist_playlists={
    "df_words_This_Is_Eminem": df_words_This_Is_Eminem.count()/43,
    "df_words_This_Is_The_Beatles": df_words_This_Is_The_Beatles.count()/29,
    "df_words_This_Is_Prince": df_words_This_Is_Prince.count()/58,
    "df_words_This_Is_Nina_Simone": df_words_This_Is_Nina_Simone.count()/31, 
    "df_words_This_Is_Lady_Gaga": df_words_This_Is_Lady_Gaga.count()/28, 
    "df_words_This_Is_Justin_Bieber": df_words_This_Is_Justin_Bieber.count()/38, 
    "df_words_This_Is_John_Mayer": df_words_This_Is_John_Mayer.count()/32, 
    "df_words_This_Is_Depeche_Mode": df_words_This_Is_Depeche_Mode.count()/13, 
    "df_words_This_Is_Ed_Sheeran": df_words_This_Is_Ed_Sheeran.count()/31, 
    "df_words_This_Is_Aretha_Franklin": df_words_This_Is_Aretha_Franklin.count()/33, 
    "df_words_This_Is_Adele": df_words_This_Is_Adele.count()/25 ,
    "df_words_This_Is_Tom_Petty": df_words_This_Is_Tom_Petty.count()/42 ,
    "df_words_This_Is_Metallica": df_words_This_Is_Metallica.count()/50 ,
    "df_words_This_Is_Madonna": df_words_This_Is_Madonna.count()/17 ,
    "df_words_This_Is_Stevie_Wonder": df_words_This_Is_Stevie_Wonder.count()/19 ,
    "df_words_This_Is_Earth_Wind_And_Fire": df_words_This_Is_Earth_Wind_And_Fire.count()/12 ,
    "df_words_This_Is_Drake": df_words_This_Is_Drake.count()/12 ,
    "df_words_This_Is_Elton_John": df_words_This_Is_Elton_John.count()/14 ,
    "df_words_This_Is_Radiohead": df_words_This_Is_Radiohead.count()/42 ,
    "df_words_This_Is_Kendrick_Lamar": df_words_This_Is_Kendrick_Lamar.count()/33,
    "df_words_This_Is_Frank_Sinatra": df_words_This_Is_Frank_Sinatra.count()/19,
    "df_words_This_Is_Red_Hot_Chili_Peppers": df_words_This_Is_Red_Hot_Chili_Peppers.count()/29,
    "df_words_This_Is_Michael_Buble": df_words_This_Is_Michael_Buble.count()/20,
    "df_words_This_Is_Beyonce": df_words_This_Is_Beyonce.count()/26,
    "df_words_This_Is_John_Legend": df_words_This_Is_John_Legend.count()/27,
    "df_words_This_Is_ACDC": df_words_This_Is_ACDC.count()/21
    
}
artist_collection=pd.DataFrame.from_dict(artist_playlists)
gender_playlists={
    "df_words_Top_Male_Artists_of_2018": df_words_Top_Male_Artists_of_2018.count()/33,
    "df_words_Top_Female_Artists_of_2018": df_words_Top_Female_Artists_of_2018.count()/34,
}
gender_collection=pd.DataFrame.from_dict(gender_playlists)

# %%
df_words_All_Out_50s=df_words_All_Out_50s.rename(index=str, columns={"count": "All Out 50s"})
df_words_All_Out_60s=df_words_All_Out_60s.rename(index=str, columns={"count": "All Out 60s"})
df_words_All_Out_70s=df_words_All_Out_70s.rename(index=str, columns={"count": "All Out 70s"})
df_words_All_Out_80s=df_words_All_Out_80s.rename(index=str, columns={"count": "All Out 80s"})
df_words_All_Out_90s=df_words_All_Out_90s.rename(index=str, columns={"count": "All Out 90s"})
df_words_All_Out_00s=df_words_All_Out_00s.rename(index=str, columns={"count": "All Out 00s"})
df_words_All_Out_10s=df_words_All_Out_10s.rename(index=str, columns={"count": "All Out 10s"})
df_words_United_States_Top_50=df_words_United_States_Top_50.rename(index=str, columns={"count": "US Top 50"})
df_words_Top_Male_Artists_of_2018=df_words_Top_Male_Artists_of_2018.rename(index=str, columns={"count": "Top_Male_Artists_of_2018"})
df_words_Top_Female_Artists_of_2018=df_words_Top_Female_Artists_of_2018.rename(index=str, columns={"count": "Top_Female_Artists_of_2018"})
df_words_This_Is_Eminem=df_words_This_Is_Eminem.rename(index=str, columns={"count": "Eminem"})
df_words_This_Is_The_Beatles=df_words_This_Is_The_Beatles.rename(index=str, columns={"count": "Beatles"})
df_words_This_Is_Prince=df_words_This_Is_Prince.rename(index=str, columns={"count": "Prince"})
df_words_This_Is_Nina_Simone=df_words_This_Is_Nina_Simone.rename(index=str, columns={"count": "Nina Simone"})
df_words_This_Is_Lady_Gaga=df_words_This_Is_Lady_Gaga.rename(index=str, columns={"count": "Lady Gaga"})
df_words_This_Is_Justin_Bieber=df_words_This_Is_Justin_Bieber.rename(index=str, columns={"count": "Justin Bieber"})
df_words_This_Is_John_Mayer=df_words_This_Is_John_Mayer.rename(index=str, columns={"count": "John Mayer"})
df_words_This_Is_Depeche_Mode=df_words_This_Is_Depeche_Mode.rename(index=str, columns={"count": "Depeche Mode"})
df_words_This_Is_Ed_Sheeran=df_words_This_Is_Ed_Sheeran.rename(index=str, columns={"count": "Ed Sheeran"})
df_words_This_Is_Aretha_Franklin=df_words_This_Is_Aretha_Franklin.rename(index=str, columns={"count": "Aretha Franklin"})
df_words_This_Is_Ed_Sheeran=df_words_This_Is_Ed_Sheeran.rename(index=str, columns={"count": "Ed Sheeran"})
df_words_This_Is_Adele=df_words_This_Is_Adele.rename(index=str, columns={"count": "Adele"})
df_words_This_Is_Tom_Petty=df_words_This_Is_Tom_Petty.rename(index=str, columns={"count": "Tom Petty"})
df_words_This_Is_Metallica=df_words_This_Is_Metallica.rename(index=str, columns={"count": "Metallica"})
df_words_This_Is_Madonna=df_words_This_Is_Madonna.rename(index=str, columns={"count": "Madonna"})
df_words_This_Is_Stevie_Wonder=df_words_This_Is_Stevie_Wonder.rename(index=str, columns={"count": "Stevie Wonder"})
df_words_This_Is_Earth_Wind_And_Fire=df_words_This_Is_Earth_Wind_And_Fire.rename(index=str, columns={"count": "Earth Wind And Fire"})
df_words_This_Is_Drake=df_words_This_Is_Drake.rename(index=str, columns={"count": "Drake"})
df_words_This_Is_Elton_John=df_words_This_Is_Elton_John.rename(index=str, columns={"count": "Elton John"})
df_words_This_Is_Radiohead=df_words_This_Is_Radiohead.rename(index=str, columns={"count": "Radiohead"})
df_words_This_Is_Kendrick_Lamar=df_words_This_Is_Kendrick_Lamar.rename(index=str, columns={"count": "Kendrick_Lamar"})
df_words_This_Is_Frank_Sinatra=df_words_This_Is_Frank_Sinatra.rename(index=str, columns={"count": "Frank_Sinatra"})
df_words_This_Is_Red_Hot_Chili_Peppers=df_words_This_Is_Red_Hot_Chili_Peppers.rename(index=str, columns={"count": "Red Hot Chili Peppers"})
df_words_This_Is_Michael_Buble=df_words_This_Is_Michael_Buble.rename(index=str, columns={"count": "Michael Buble"})
df_words_This_Is_Beyonce=df_words_This_Is_Beyonce.rename(index=str, columns={"count": "Beyonce"})
df_words_This_Is_John_Legend=df_words_This_Is_John_Legend.rename(index=str, columns={"count": "John Legend"})
df_words_This_Is_ACDC=df_words_This_Is_ACDC.rename(index=str, columns={"count": "ACDC"})

dataframes=[
df_words_All_Out_50s,
df_words_All_Out_60s,
df_words_All_Out_70s,
df_words_All_Out_80s,
df_words_All_Out_90s,
df_words_All_Out_00s,
df_words_All_Out_10s,
df_words_United_States_Top_50,
df_words_Top_Male_Artists_of_2018,
df_words_Top_Female_Artists_of_2018,
df_words_This_Is_Eminem,
df_words_This_Is_The_Beatles,
df_words_This_Is_Prince,
df_words_This_Is_Nina_Simone,
df_words_This_Is_Lady_Gaga,
df_words_This_Is_Justin_Bieber,
df_words_This_Is_John_Mayer,
df_words_This_Is_Depeche_Mode,
df_words_This_Is_Ed_Sheeran,
df_words_This_Is_Aretha_Franklin,
df_words_This_Is_Ed_Sheeran,
df_words_This_Is_Adele,
df_words_This_Is_Tom_Petty,
df_words_This_Is_Metallica,
df_words_This_Is_Madonna,
df_words_This_Is_Stevie_Wonder,
df_words_This_Is_Earth_Wind_And_Fire,
df_words_This_Is_Drake,
df_words_This_Is_Elton_John,
df_words_This_Is_Radiohead,
df_words_This_Is_Kendrick_Lamar,
df_words_This_Is_Frank_Sinatra,
df_words_This_Is_Red_Hot_Chili_Peppers,
df_words_This_Is_Michael_Buble,
df_words_This_Is_Beyonce,
df_words_This_Is_John_Legend,
df_words_This_Is_ACDC
]

result = pd.concat(dataframes, axis=1, sort=False)
result['All Playlists'] = result.sum(axis=1)
result.to_csv('Output_Files/results.csv')

result_avg = pd.DataFrame.from_dict(playlist_avg_per_song)
result_avg['All Playlists'] = result_avg.sum(axis=1)
result_avg.to_csv('Output_Files/results_avg.csv')



results_summary=result.sort_values("All Playlists", ascending=False)
results_summary=results_summary.append(results_summary.sum(numeric_only=True), ignore_index=True)



result=result.sort_values("All Playlists", ascending=False)

# %%
file_one = "results.csv" 
file_two = "results_avg.csv" 

file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1") 
file_one_df=file_one_df.set_index("Unnamed: 0")
column_names=list(file_one_df)

file_two_df = pd.read_csv(file_two, encoding="ISO-8859-1") 
file_two_df=file_two_df.set_index("Unnamed: 0")
column_names_1=list(file_two_df)

file_one_df=file_one_df[["All Out 50s", "All Out 60s", "All Out 70s", "All Out 80s", "All Out 90s", "All Out 00s", "All Out 10s", "US Top 50"]]
file_one_df

# %%
variety_words=pd.DataFrame(file_one_df.count())

variety_words

# %%
x_axis=list(file_one_df)
y_axis=variety_words.apply(lambda x: x.tolist(), axis=1)

# %%
plt.bar(x_axis, y_axis, color='c', alpha=0.5, align="center",width=.5)
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, x_axis, rotation='vertical')
plt.title("Count of Unique Words by Playlist")
plt.xlabel("Playlists")
plt.ylabel("Count of Words")
plt.grid()
plt.tight_layout()
plt.savefig("Output_Files/unique_words_plot.png")
plt.show()

# %%
file_one_df_1 = pd.read_csv(file_one, encoding="ISO-8859-1") 
file_one_df_1=file_one_df_1.set_index("Unnamed: 0")

file_one_df_1=file_one_df_1[['Eminem','Beatles','Prince','Nina Simone','Lady Gaga','Justin Bieber','John Mayer','Depeche Mode','Ed Sheeran','Aretha Franklin','Ed Sheeran.1','Adele','Tom Petty','Metallica','Madonna','Stevie Wonder','Earth Wind And Fire','Drake','Elton John','Radiohead','Kendrick_Lamar','Frank_Sinatra','Red Hot Chili Peppers','Michael Buble','Beyonce','John Legend','ACDC']]

file_one_df_1=file_one_df_1.drop(columns=['Ed Sheeran.1'])
file_one_df_1

# %%
variety_words_artists=pd.DataFrame(file_one_df_1.count()).sort_values(0, ascending=False)

variety_words_artists=variety_words_artists
variety_words_artists

# %%
x_axis=list(file_one_df_1)
y_axis=variety_words_artists.apply(lambda x: x.tolist(), axis=1)

plt.bar(x_axis, y_axis, color='r', alpha=0.5, align="center",width=.5)

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, x_axis, rotation='vertical')
plt.title("Count of Unique Words by Artist")
plt.xlabel("Artist")
plt.ylabel("Count of Words")
plt.tight_layout()
plt.grid()
plt.savefig("Output_Files/unique_words_artist_plot.png")
plt.show()

# %%
#Average Unique Words Per Song
file_two_df = pd.read_csv(file_two, encoding="ISO-8859-1") 
file_two_df=file_two_df.set_index("Unnamed: 0")
file_two_df=file_two_df.T.sort_values('count', ascending=False)

artists_avg=[]

for items in file_two_df.index.values:
    if "This_Is" in items:
        artists_avg.append(items)
        
#artists_avg

# %%
all_artists=[]
all_values=[]

for index, row in file_two_df.iterrows():
    if index in artists_avg:
        all_artists.append(index)
        
all_artists

# %%
import re

df_names_artists=file_two_df.loc[all_artists]
df_names_artists=df_names_artists.reset_index()

names_artist=df_names_artists['index'].values.tolist()

cleaned_index=[]
for items in names_artist:
    cleaned_item=re.sub(r'_', ' ',items)
    cleaned_index.append(cleaned_item)
cleaned_index_1=[]
for items in cleaned_index:
    cleaned_item=re.sub(r'df words This Is ', '',items)
    cleaned_index_1.append(cleaned_item)
      
cleaned_index_1

# %%
barWidth = 0.5
 
x_axis = cleaned_index_1
y_axis = df_names_artists['count'].tolist()

plt.bar(x_axis, y_axis, color='c', alpha=0.5, align="center",width=.5)

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, x_axis, rotation='vertical')
plt.title("Count of Unique Words per Song by Artist")
plt.xlabel("Artist")
plt.ylabel("Count of Words")
plt.tight_layout()
plt.grid()
plt.savefig("Output_Files/unique_words_artist_song_plot.png")
plt.show()
