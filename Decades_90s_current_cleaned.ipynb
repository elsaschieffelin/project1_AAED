# %%
#Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Read csv files
csv_pathc = "lyrics_output/df_words_United_States_Top_50.csv"
csv_path1 = "lyrics_output/df_words_All_Out_10s.csv"
csv_path0 = "lyrics_output/df_words_All_Out_00s.csv"
csv_path9 = "lyrics_output/df_words_All_Out_90s.csv"

# %%
#Create dataframe
df_c = pd.read_csv(csv_pathc)
df_10s = pd.read_csv(csv_path1)
df_00s = pd.read_csv(csv_path0)
df_90s = pd.read_csv(csv_path9)

# %%
#Read in top 50 most commonly used English words (OEC standard)
lines = list()
fh = open("top50_words.txt")
for line in fh:
    line = line.rstrip()
    lines.append(line)
lines
# Out:
# ['be',
#  'to',
#  'of',
#  'and',
#  'a',
#  'in',
#  'that',
#  'have',
#  'i',
#  'it',
#  'for',
#  'not',
#  'on',
#  'with',
#  'he',
#  'as',
#  'you',
#  'do',
#  'at',
#  'this',
#  'but',
#  'his',
#  'by',
#  'from',
#  'they',
#  'we',
#  'say',
#  'her',
#  'she',
#  'or',
#  'an',
#  'will',
#  'my',
#  'one',
#  'all',
#  'would',
#  'there',
#  'their',
#  'what',
#  'so',
#  'up',
#  'out',
#  'if',
#  'about',
#  'who',
#  'get',
#  'which',
#  'go',
#  'me',
#  'when',
#  '']

# %%
#Sorting and editing
df_current = df_c.sort_values("count", ascending = False)
df_current = df_current.rename(columns = {"Unnamed: 0": "words"})
df_current.head()
# Out:
#    words  count
# 39     i   1083
# 13   you    973
# 17   the    696
# 11     a    520
# 50    my    408

# %%
#Remove most common English words
df_cleaned=df_current[~df_current['words'].isin(lines)]
df_cleaned.head(25)
# Out:
#        words  count
# 17       the    696
# 20       i'm    385
# 19      yeah    331
# 131     like    218
# 73        no    190
# 53      know    177
# 260      got    163
# 159     love    162
# 109    wanna    146
# 255     your    140
# 1073   fight    139
# 83     don't    139
# 550     next    133
# 175    ain't    123
# 143     fuck    123
# 214     just    122
# 56    chorus    121
# 285       is    120
# 54      it's    118
# 384    thank    112
# 0      verse    105
# 43     can't    104
# 954    taste    100
# 152     want     96
# 119      can     88

# %%
df_current_sample = df_cleaned.head(10)

# %%
#Create bar chart
words_10 = df_current_sample["words"]
x_axis = np.arange(len(words_10))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, df_current_sample['count'], color=('c','c','c','c','c','y','y','y','y','y'), alpha=0.5, align='center')
plt.xticks(tick_locations, words_10, rotation='vertical')
plt.title("Top 10 words in current US Top 50 Hits")
plt.xlabel("Words")
plt.ylabel("Word Frequency")
plt.savefig("decade_charts/10_top_words_current.png")
plt.show()

# %%
#Sorting and editing
df_10s=df_10s.sort_values("count", ascending = False)
df_10s = df_10s.rename(columns={"Unnamed: 0": "words"})

# %%
#Remove most common English words
df_cleaned=df_10s[~df_10s['words'].isin(lines)]

# %%
df_10s_sample = df_cleaned.head(10)
df_10s_sample
# Out:
#      words  count
# 11     the    483
# 13     i'm    212
# 21    your    199
# 101   know    170
# 169     oh    162
# 532   yeah    159
# 79   don't    156
# 90    like    151
# 262   love    142
# 648  'bout    137

# %%
#Create bar chart
words_10 = df_10s_sample["words"]
x_axis = np.arange(len(words_10))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, df_10s_sample['count'], color=('c','c','c','c','c','y','y','y','y','y'), alpha=0.5, align='center')
plt.xticks(tick_locations, words_10, rotation='vertical')
plt.title("Top 10 words in 2010s' Top Songs")
plt.xlabel("Words")
plt.ylabel("Word Frequency")
plt.savefig("decade_charts/10_top_words_2010s.png")
plt.show()

# %%
#Sorting and editing
df_00s = df_00s.sort_values("count", ascending = False)
df_00s = df_00s.rename(columns = {"Unnamed: 0": "words"})

# %%
#Remove most common English words
df_cleaned=df_00s[~df_00s['words'].isin(lines)]
df_cleaned.head(20)
# Out:
#       words  count
# 10      the    764
# 44     your    464
# 190     i'm    376
# 81     just    203
# 404   hands    196
# 95       no    187
# 650   what?    181
# 79       oh    177
# 883      la    162
# 242    love    161
# 220    yeah    156
# 39     like    151
# 253    know    139
# 51   chorus    136
# 35    don't    130
# 121   verse    127
# 99       is    112
# 198     can    112
# 114    it's    106
# 37     baby    100

# %%
df_00s_sample = df_cleaned.head(10)
df_00s_sample
# Out:
#      words  count
# 10     the    764
# 44    your    464
# 190    i'm    376
# 81    just    203
# 404  hands    196
# 95      no    187
# 650  what?    181
# 79      oh    177
# 883     la    162
# 242   love    161

# %%
#Create bar chart
words_10 = df_00s_sample["words"]
x_axis = np.arange(len(words_10))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, df_00s_sample['count'], color=('c','c','c','c','c','y','y','y','y','y'), alpha=0.5, align='center')
plt.xticks(tick_locations, words_10, rotation='vertical')
plt.title("Top 10 words in 2000s' Top Songs")
plt.xlabel("Words")
plt.ylabel("Word Frequency")
plt.savefig("decade_charts/10_top_words_2000s.png")
plt.show()

# %%
#Sorting and editing
df_90s = df_90s.sort_values("count", ascending = False)
df_90s = df_90s.rename(columns = {"Unnamed: 0": "words"})

#Remove most common English words
df_cleaned=df_90s[~df_90s['words'].isin(lines)]
df_cleaned.head(25)

# %%
df_90s_sample = df_cleaned.head(10)
df_90s_sample
# Out:
#      words  count
# 10     the    764
# 44    your    464
# 190    i'm    376
# 81    just    203
# 404  hands    196
# 95      no    187
# 650  what?    181
# 79      oh    177
# 883     la    162
# 242   love    161

# %%
#Create bar chart
words_10 = df_90s_sample["words"]
x_axis = np.arange(len(words_10))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, df_90s_sample['count'], color=('c','c','c','c','c','y','y','y','y','y'), alpha=0.5, align='center')
plt.xticks(tick_locations, words_10, rotation='vertical')
plt.title("Top 10 words in 1990s' Top Songs")
plt.xlabel("Words")
plt.ylabel("Word Frequency")
plt.savefig("decade_charts/10_top_words_1990s.png")
plt.show()
